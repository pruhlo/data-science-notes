# %% [markdown]
# # Ієрархічна кластеризація

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt
import numpy as np

# Для відтворювання графіки
# %matplotlib inline

# Наші дані
points = np.array([[1,2], [2,1], [2,2], [1,3], [6,7], [6,5], [7,8], [8,8]], dtype=float)

Z = linkage(points, 'ward')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(Z)

plt.show()

# %%
# for R!!!
#!pip install rpy2
import rpy2.ipython
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# from rpy2.robjects.packages import importr
# # import R's "base" package
# ggrepel = importr('ggrepel')

# %%
# %%R
# library(ggrepel)

# %%
# %%R
# x <- rnorm(10)
# y <- rnorm(10)
# test_data <- data.frame(x, y)
# test_data$labels <- 1:10
# #library(ggplot2)
# #library(ggrepel) # для гарного підпису точок на графіку
# ggplot2::ggplot(test_data, ggplot2::aes(x, y, label = labels))+
#     ggplot2::geom_point()#+
#     #ggplot2::geom_text_repel()
#
# d = dist(test_data)
# fit <- hclust(d, method = "single")
# plot(fit, labels = test_data$labels)
# rect.hclust(fit, 3) # вкажіть бажану кількість кластерів, зараз встановлено 2

# %%
# %%R
# x
# Out:
#  [1] -1.97985916 -0.15907901  1.02203852 -0.05563099  1.06086342  1.40471111
#  [7]  0.25736386  1.03848985 -0.97402070  0.47817809
